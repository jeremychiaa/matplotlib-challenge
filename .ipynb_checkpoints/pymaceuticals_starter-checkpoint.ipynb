# %% [markdown]
# ## Observations and Insights

# %%
# %matplotlib inline

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "Resources/Mouse_metadata.csv"
study_results_path = "Resources/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combined_data = pd.merge(mouse_metadata, study_results, on="Mouse ID", how="outer")

# Display the data table for preview
combined_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %%
# Checking the number of mice.
total_mice = combined_data["Mouse ID"].nunique()
total_mice
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
# Creating a groupby on Mouse ID and Timepoint
grouped_mice = combined_data.groupby(["Mouse ID", "Timepoint"])

# Count and sort the number of drug regimens each mice received
mice_regimen = grouped_mice["Drug Regimen"].count().sort_values()

# Retrieve the duplicate mice that received more than one regimen
mice_regimen.tail()
# Out:
# Mouse ID  Timepoint
# g989      20           2
#           5            2
#           10           2
#           0            2
#           15           2
# Name: Drug Regimen, dtype: int64

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mice = combined_data.loc[combined_data["Mouse ID"] == "g989"]
duplicate_mice
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# 911           47.570392                 0
# 912           51.745156                 0
# 913           49.880528                 0
# 914           51.325852                 1
# 915           53.442020                 0
# 916           55.326122                 1
# 917           54.657650                 1
# 918           56.045564                 1
# 919           59.082294                 1
# 920           62.570880                 2

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
combined_data = combined_data.drop(combined_data[combined_data["Mouse ID"] == "g989"].index.values)
combined_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1880 rows x 8 columns]

# %%
# Checking the number of mice in the clean DataFrame.
cleaned_total_mice = combined_data["Mouse ID"].nunique()
cleaned_total_mice
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method is the most straighforward, creating multiple series and putting them all together at the end.
grouped_summary = combined_data.groupby(["Drug Regimen"])
mean_summary = pd.Series(grouped_summary["Tumor Volume (mm3)"].mean(), name = "Mean")
median_summary = pd.Series(grouped_summary["Tumor Volume (mm3)"].median(), name = "Median")
variance_summary = pd.Series(grouped_summary["Tumor Volume (mm3)"].var(), name = "Variance")
stddev_summary = pd.Series(grouped_summary["Tumor Volume (mm3)"].std(), name = "Std Dev")
sem_summary = pd.Series(grouped_summary["Tumor Volume (mm3)"].sem(), name = "SEM")

summary_stats = pd.concat([mean_summary, median_summary, variance_summary, stddev_summary, sem_summary], axis=1)
summary_stats
# Out:
#                    Mean     Median   Variance   Std Dev       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method produces everything in a single groupby function
summary_stats_groupby = combined_data.groupby(["Drug Regimen"]).agg(["mean", "median", "var", "std", "sem"])
summary_stats_groupby["Tumor Volume (mm3)"]
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
# Split up our data into groups based upon 'drug regimen'
grouped_drugs = combined_data.groupby(["Drug Regimen"])

# Find out how many mice took each drug
total_mice = grouped_drugs["Mouse ID"].nunique()

# Chart the data, providing it with a title and labels
total_mice_chart_pd = total_mice.plot(kind="bar", title="Total Number of Mice for each Drug Treatment")
total_mice_chart_pd.set_xlabel("Drug Regimen")
total_mice_chart_pd.set_ylabel("Number of Mice")

plt.tight_layout()
plt.show()

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.
# Assign total mice to new variable
# mice_count = total_mice

# Set mice count index to default index
mice_count = total_mice.reset_index()

# Assign axis values
x_axis = mice_count["Drug Regimen"]
y_axis = mice_count["Mouse ID"]

# Plot bar chart
plt.bar(x_axis, y_axis)
plt.xticks(rotation=90)

# Give chart title and labels
plt.title("Total Number of Mice for each Drug Treatment")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice")

plt.tight_layout()
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
# Group data by gender
gender_grouped = combined_data.groupby(["Sex"])

# Find gender distribution
gender_distribution = gender_grouped["Mouse ID"].nunique()

# Plot pie chart based on data
mice_gender_chart_pd = gender_distribution.plot(kind="pie", title="Gender Distribution of Mice", autopct="%1.1f%%")

# Show chart that was created
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
gender = ["Male", "Female"]

# Using matplotlib.pyplot to create a pie chart based on above data
plt.pie(gender_distribution, labels=gender, autopct="%1.1f%%")

# Create axes which are equal so we have a perfect circle
plt.axis("equal")

# Show chart that was created
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Start by getting the last (greatest) timepoint for each mouse

# Retrieve data of the four treatment regimens
reduced_data = combined_data.loc[combined_data["Drug Regimen"] == "Capomulin"]
reduced_data = reduced_data.append(combined_data.loc[combined_data["Drug Regimen"] == "Ramicane"])
reduced_data = reduced_data.append(combined_data.loc[combined_data["Drug Regimen"] == "Infubinol"])
reduced_data = reduced_data.append(combined_data.loc[combined_data["Drug Regimen"] == "Ceftamin"])

# Group dataframe by Mouse ID and Timepoint
grouped_reduced_data = reduced_data.groupby(["Mouse ID", "Timepoint"])

# Retrieve tumour volumes
tumour_volume = grouped_reduced_data["Tumor Volume (mm3)"].max()

# Change to default index
tumour_volume = tumour_volume.reset_index()

# Retrieve data with the max timepoint of 45
last_timepoint = tumour_volume.loc[tumour_volume["Timepoint"] == 45]
last_timepoint

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
new_combined_data = pd.merge(combined_data, last_timepoint, on=("Mouse ID", "Timepoint"), how="left", suffixes=("","(final)"))
new_combined_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1875     z969     Naftisol  Male           9          30         25
# 1876     z969     Naftisol  Male           9          30         30
# 1877     z969     Naftisol  Male           9          30         35
# 1878     z969     Naftisol  Male           9          30         40
# 1879     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites  Tumor Volume (mm3)(final)
# 0              45.000000                 0                        NaN
# 1              38.825898                 0                        NaN
# 2              35.014271                 1                        NaN
# 3              34.223992                 1                        NaN
# 4              32.997729                 1                        NaN
# ...                  ...               ...                        ...
# 1875           63.145652                 2                        NaN
# 1876           65.841013                 3                        NaN
# 1877           69.176246                 4                        NaN
# 1878           70.314904                 4                        NaN
# 1879           73.867845                 4                        NaN
#
# [1880 rows x 9 columns]

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments_list = new_combined_data["Drug Regimen"].unique().tolist()
treatments_list

# Create empty list to fill with tumor vol data (for plotting)
tumour_data = new_combined_data["Tumor Volume (mm3)"]
tumour_data

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
quartiles = tumour_data.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq - lowerq

print(f"The lower quartile of tumour volume is: {lowerq} mm3")
print(f"The upper quartile of tumour volume is: {upperq} mm3")
print(f"The interquartile range of tumour volume is: {iqr} mm3")
print(f"The the median of tumour volume is: {quartiles[0.5]} mm3")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)

print(f"Values below {lower_bound} mm3 could be outliers.")
print(f"Values above {upper_bound} mm3 could be outliers.")

tumour_data.sort_values()
    
# Locate the rows which contain mice on each drug and get the tumor volumes
# Retrieve Capomulin, Ramicane, Infubinol, and Ceftamin data
cleaned_capomulin = new_combined_data.loc[new_combined_data["Drug Regimen"] == "Capomulin"]
cleaned_ramicane = new_combined_data.loc[new_combined_data["Drug Regimen"] == "Ramicane"]
cleaned_infubinol = new_combined_data.loc[new_combined_data["Drug Regimen"] == "Infubinol"]
cleaned_ceftamin = new_combined_data.loc[new_combined_data["Drug Regimen"] == "Ceftamin"]

# Retrieve drug regimen and newly created column
cleaned_capomulin = cleaned_capomulin[["Drug Regimen","Tumor Volume (mm3)(final)"]]
cleaned_ramicane = cleaned_ramicane[["Drug Regimen","Tumor Volume (mm3)(final)"]]
cleaned_infubinol = cleaned_infubinol[["Drug Regimen","Tumor Volume (mm3)(final)"]]
cleaned_ceftamin = cleaned_ceftamin[["Drug Regimen","Tumor Volume (mm3)(final)"]]

# Drop all null values
cleaned_capomulin = cleaned_capomulin.dropna()
cleaned_ramicane = cleaned_ramicane.dropna()
cleaned_infubinol = cleaned_infubinol.dropna()
cleaned_ceftamin = cleaned_ceftamin.dropna()

# add subset 
# Merge all four dataframes together
box_data = pd.merge(cleaned_capomulin, cleaned_ramicane, on=("Drug Regimen","Tumor Volume (mm3)(final)"), how="outer")
box_data = pd.merge(box_data, cleaned_infubinol, on=("Drug Regimen","Tumor Volume (mm3)(final)"), how="outer")
box_data = pd.merge(box_data, cleaned_ceftamin, on=("Drug Regimen","Tumor Volume (mm3)(final)"), how="outer")

# Determine outliers using upper and lower bounds
box_quartiles = box_data["Tumor Volume (mm3)(final)"].quantile([.25,.5,.75])
box_lowerq = quartiles[0.25]
box_upperq = quartiles[0.75]
box_iqr = box_upperq - box_lowerq
box_lower_bound = box_lowerq - (1.5*box_iqr)
box_upper_bound = box_upperq + (1.5*box_iqr)
# Out:
# The lower quartile of tumour volume is: 45.0 mm3
# The upper quartile of tumour volume is: 56.32407510749999 mm3
# The interquartile range of tumour volume is: 11.324075107499993 mm3
# The the median of tumour volume is: 48.933453655 mm3
# Values below 28.01388733875001 mm3 could be outliers.
# Values above 73.31018776874998 mm3 could be outliers.
#    Drug Regimen  Tumor Volume (mm3)(final)
# 0     Capomulin                  23.343598
# 1     Capomulin                  28.484033
# 2     Capomulin                  28.430964
# 3     Capomulin                  31.023923
# 4     Capomulin                  31.896238
# ..          ...                        ...
# 58     Ceftamin                  67.527482
# 59     Ceftamin                  64.634949
# 60     Ceftamin                  61.386660
# 61     Ceftamin                  68.594745
# 62     Ceftamin                  64.729837
#
# [63 rows x 2 columns]

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
